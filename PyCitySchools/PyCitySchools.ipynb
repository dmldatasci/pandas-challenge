# %% [markdown]
# # School District Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending 645-675 per student actually underperformed compared to schools with smaller budgets (585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %%
import pandas as pd
import os

schools_file_path = os.path.join('Resources', 'schools_complete.csv')
schools_frame = pd.read_csv(schools_file_path)

students_file_path = os.path.join('Resources', 'students_complete.csv')
students_frame = pd.read_csv(students_file_path)

# %%
schools_frame.head(3)
# Out:
#    School ID           school_name      type  size   budget
# 0          0     Huang High School  District  2917  1910635
# 1          1  Figueroa High School  District  2949  1884411
# 2          2   Shelton High School   Charter  1761  1056600

# %%
students_frame.head(3)
# Out:
#    Student ID     student_name gender grade        school_name  reading_score
# 0           0     Paul Bradley      M   9th  Huang High School             66  \
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
#
#    math_score
# 0          79
# 1          61
# 2          60

# %% [markdown]
# ## District Summary

# %%
# extract total number of unique schools
school_count = len(schools_frame['School ID'].unique())
school_count
# Out:
# 15

# %%
# extract the total number of unique students
student_count = len(students_frame['Student ID'])
student_count
# Out:
# 39170

# %%
# extract the total budget for the district
budget = schools_frame['budget'].sum()
budget
# Out:
# 24649428

# %%
# calculate the average math score
avg_math_score = students_frame['math_score'].mean()
avg_math_score
# Out:
# 78.98537145774827

# %%
# calculate the average math score
avg_read_score = students_frame['reading_score'].mean()
avg_read_score
# Out:
# 81.87784018381414

# %%
# calculate percent of students who passed math
math_pass_percentage = len(students_frame[students_frame['math_score'] >= 70]) / student_count * 100
math_pass_percentage
# Out:
# 74.9808526933878

# %%
# calculate percentage of students who passed reading
read_pass_percentage = len(students_frame[students_frame['reading_score'] >= 70]) / student_count * 100
read_pass_percentage
# Out:
# 85.80546336482001

# %%
# calculate percentage of students who passed both math & reading
mr_pass_percentage = len(students_frame[(students_frame['math_score'] >= 70) & (students_frame['reading_score'] >= 70)]) / student_count * 100
mr_pass_percentage
# Out:
# 65.17232575950983

# %%
# construct an appropriate dataframe
district_summary = pd.DataFrame({
    'Total Schools' : [school_count],
    'Total Students' : [student_count],
    'Total Budget' : [budget],
    'Average Math Score' : [avg_math_score],
    'Average Reading Score' : [avg_read_score],
    '% Passing Math' : [math_pass_percentage],
    '% Passing Reading' : [read_pass_percentage],
    '% Overall Passing' : [mr_pass_percentage]})

# format relevant values from the dataframe
district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,.2f}".format)

district_summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score
# 0             15         39,170  $24,649,428.00           78.985371  \
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %%
# construct a new dataframe with the information we need and to which we can add calculations
per_school_summary = schools_frame.rename(columns={
    'school_name' : 'School Name',
    'type' : 'School Type',
    'size' : 'Total Students',
    'budget' : 'Total School Budget'
    }).sort_values(by=['School Name']).set_index(['School Name'])

per_school_summary
# Out:
#                        School ID School Type  Total Students
# School Name
# Bailey High School             7    District            4976  \
# Cabrera High School            6     Charter            1858
# Figueroa High School           1    District            2949
# Ford High School              13    District            2739
# Griffin High School            4     Charter            1468
# Hernandez High School          3    District            4635
# Holden High School             8     Charter             427
# Huang High School              0    District            2917
# Johnson High School           12    District            4761
# Pena High School               9     Charter             962
# Rodriguez High School         11    District            3999
# Shelton High School            2     Charter            1761
# Thomas High School            14     Charter            1635
# Wilson High School             5     Charter            2283
# ...

# %%
# `schools_frame` already contains school type
per_school_summary['School Type']
# Out:
# School Name
# Bailey High School       District
# Cabrera High School       Charter
# Figueroa High School     District
# Ford High School         District
# Griffin High School       Charter
# Hernandez High School    District
# Holden High School        Charter
# Huang High School        District
# Johnson High School      District
# Pena High School          Charter
# Rodriguez High School    District
# Shelton High School       Charter
# Thomas High School        Charter
# Wilson High School        Charter
# Wright High School        Charter
# Name: School Type, dtype: object

# %%
# `schools_frame` already contains total students
per_school_summary['Total Students']
# Out:
# School Name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Total Students, dtype: int64

# %%
# calculate per student budget
per_school_summary['Per Student Budget'] = per_school_summary['Total School Budget'] / per_school_summary['Total Students']
per_school_summary
# Out:
#                        School ID School Type  Total Students
# School Name
# Bailey High School             7    District            4976  \
# Cabrera High School            6     Charter            1858
# Figueroa High School           1    District            2949
# Ford High School              13    District            2739
# Griffin High School            4     Charter            1468
# Hernandez High School          3    District            4635
# Holden High School             8     Charter             427
# Huang High School              0    District            2917
# Johnson High School           12    District            4761
# Pena High School               9     Charter             962
# Rodriguez High School         11    District            3999
# Shelton High School            2     Charter            1761
# Thomas High School            14     Charter            1635
# Wilson High School             5     Charter            2283
# ...

# %%
# calculate average math score
avg_scores = students_frame[['school_name', 'math_score', 'reading_score']].groupby(['school_name']).mean()
per_school_summary['Average Math Score'] = avg_scores['math_score']
per_school_summary['Average Reading Score'] = avg_scores['reading_score']
per_school_summary
# Out:
#                        School ID School Type  Total Students
# School Name
# Bailey High School             7    District            4976  \
# Cabrera High School            6     Charter            1858
# Figueroa High School           1    District            2949
# Ford High School              13    District            2739
# Griffin High School            4     Charter            1468
# Hernandez High School          3    District            4635
# Holden High School             8     Charter             427
# Huang High School              0    District            2917
# Johnson High School           12    District            4761
# Pena High School               9     Charter             962
# Rodriguez High School         11    District            3999
# Shelton High School            2     Charter            1761
# Thomas High School            14     Charter            1635
# Wilson High School             5     Charter            2283
# ...

# %%
# calculate the percentage of students at each school who passed math
per_school_summary['% Passing Math'] = students_frame[students_frame['math_score'] >= 70].groupby(['school_name']).count()['math_score'] / per_school_summary['Total Students'] * 100

# calculate the percentage of students at each school who passed reading
per_school_summary['% Passing Reading'] = students_frame[students_frame['reading_score'] >= 70].groupby(['school_name']).count()['reading_score'] / per_school_summary['Total Students'] * 100

# calculate the percentage of students at each school who passed both math and reading
per_school_summary['% Overall Passing'] = students_frame[(students_frame['reading_score'] >= 70) & (students_frame['math_score'] >= 70)].groupby(['school_name']).count()['reading_score'] / per_school_summary['Total Students'] * 100

per_school_summary
# Out:
#                        School ID School Type  Total Students
# School Name
# Bailey High School             7    District            4976  \
# Cabrera High School            6     Charter            1858
# Figueroa High School           1    District            2949
# Ford High School              13    District            2739
# Griffin High School            4     Charter            1468
# Hernandez High School          3    District            4635
# Holden High School             8     Charter             427
# Huang High School              0    District            2917
# Johnson High School           12    District            4761
# Pena High School               9     Charter             962
# Rodriguez High School         11    District            3999
# Shelton High School            2     Charter            1761
# Thomas High School            14     Charter            1635
# Wilson High School             5     Charter            2283
# ...

# %%
# edit formatting for more readable output
per_school_summary['Total Students'] = per_school_summary['Total Students'].astype('int32').map("{:,}".format)
per_school_summary['Total School Budget'] = per_school_summary['Total School Budget'].map("${:,.2f}".format)
per_school_summary['Per Student Budget'] = per_school_summary['Per Student Budget'].map("${:,.2f}".format)

per_school_summary
# Out:
#                        School ID School Type Total Students
# School Name
# Bailey High School             7    District          4,976  \
# Cabrera High School            6     Charter          1,858
# Figueroa High School           1    District          2,949
# Ford High School              13    District          2,739
# Griffin High School            4     Charter          1,468
# Hernandez High School          3    District          4,635
# Holden High School             8     Charter            427
# Huang High School              0    District          2,917
# Johnson High School           12    District          4,761
# Pena High School               9     Charter            962
# Rodriguez High School         11    District          3,999
# Shelton High School            2     Charter          1,761
# Thomas High School            14     Charter          1,635
# Wilson High School             5     Charter          2,283
# ...

# %% [markdown]
# ## Highest-Performing Schools (by % Overall Passing)

# %%
# sort the schools by `% Overall Passing` in descending order and display the top 5 rows
top_schools = per_school_summary.sort_values(by=['% Overall Passing'], ascending=False).head(5)
top_schools
# Out:
#                      School ID School Type Total Students Total School Budget
# School Name
# Cabrera High School          6     Charter          1,858       $1,081,356.00  \
# Thomas High School          14     Charter          1,635       $1,043,130.00
# Griffin High School          4     Charter          1,468         $917,500.00
# Wilson High School           5     Charter          2,283       $1,319,574.00
# Pena High School             9     Charter            962         $585,858.00
#
#                     Per Student Budget  Average Math Score
# School Name
# Cabrera High School            $582.00           83.061895  \
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading
# School Name
# ...

# %% [markdown]
# ## Lowest-Performing Schools (by % Overall Passing)

# %%
# sort the schools by `% Overall Passing` in ascending order and display the top 5 rows
bottom_schools = per_school_summary.sort_values(by=['% Overall Passing']).head(5)
bottom_schools
# Out:
#                        School ID School Type Total Students
# School Name
# Rodriguez High School         11    District          3,999  \
# Figueroa High School           1    District          2,949
# Huang High School              0    District          2,917
# Hernandez High School          3    District          4,635
# Johnson High School           12    District          4,761
#
#                       Total School Budget Per Student Budget
# School Name
# Rodriguez High School       $2,547,363.00            $637.00  \
# Figueroa High School        $1,884,411.00            $639.00
# Huang High School           $1,910,635.00            $655.00
# Hernandez High School       $3,022,020.00            $652.00
# Johnson High School         $3,094,650.00            $650.00
#
#                        Average Math Score  Average Reading Score
# School Name
# Rodriguez High School           76.842711              80.744686  \
# ...

# %% [markdown]
# ## Math Scores by Grade

# %%
# define a custom sort order by declaring grade as a categorical variable
students_frame['grade'] = pd.Categorical(students_frame['grade'], ['9th', '10th', '11th', '12th'])

# create a data frame that lists the average math score for students of each grade level at each school
math_scores_by_grade = students_frame[['school_name', 'grade', 'math_score']].groupby(by=['school_name', 'grade']).mean().unstack()
math_scores_by_grade
# Out:
#                       math_score
# grade                        9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# ...

# %% [markdown]
# ## Reading Scores by Grade

# %%
# create a data frame that lists the average math score for students of each grade level at each school
reading_scores_by_grade = students_frame[['school_name', 'grade', 'reading_score']].groupby(by=['school_name', 'grade']).mean().unstack()
reading_scores_by_grade
# Out:
#                       reading_score
# grade                           9th       10th       11th       12th
# school_name
# Bailey High School        81.303155  80.907183  80.945643  80.912451
# Cabrera High School       83.676136  84.253219  83.788382  84.287958
# Figueroa High School      81.198598  81.408912  80.640339  81.384863
# Ford High School          80.632653  81.262712  80.403642  80.662338
# Griffin High School       83.369193  83.706897  84.288089  84.013699
# Hernandez High School     80.866860  80.660147  81.396140  80.857143
# Holden High School        83.677165  83.324561  83.815534  84.698795
# Huang High School         81.290284  81.512386  81.417476  80.305983
# Johnson High School       81.260714  80.773431  80.616027  81.227564
# Pena High School          83.807273  83.612000  84.335938  84.591160
# Rodriguez High School     80.993127  80.629808  80.864811  80.376426
# Shelton High School       84.122642  83.441964  84.373786  82.781671
# ...

# %% [markdown]
# ## Scores by School Spending

# %%
# start by creating a new analytic dataframe
per_school_summary_w_bins = per_school_summary

# %%
# create a data frame that breaks down school performance based on spending ranges
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

per_school_summary_w_bins['Spending Bin (Per Student)'] = pd.cut(per_school_summary_w_bins['Per Student Budget'].apply(lambda x: float(x.split('$')[1])), bins=spending_bins, labels=labels)
spending_summary = per_school_summary_w_bins[['Spending Bin (Per Student)',
    'Average Math Score',
    'Average Reading Score',
    '% Passing Math',
    '% Passing Reading',
    '% Overall Passing']].groupby(by=['Spending Bin (Per Student)']).mean()

spending_summary
# Out:
#                             Average Math Score  Average Reading Score
# Spending Bin (Per Student)
# <$585                                83.455399              83.933814  \
# $585-630                             81.899826              83.155286
# $630-645                             78.518855              81.624473
# $645-680                             76.997210              81.027843
#
#                             % Passing Math  % Passing Reading
# Spending Bin (Per Student)
# <$585                            93.460096          96.610877  \
# $585-630                         87.133538          92.718205
# $630-645                         73.484209          84.391793
# $645-680                         66.164813          81.133951
#
#                             % Overall Passing
# Spending Bin (Per Student)
# <$585                               90.369459
# $585-630                            81.418596
# $630-645                            62.857656
# ...

# %% [markdown]
# ## Scores by School Size

# %%
# create a data frame that breaks down school performance based on size ranges
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

per_school_summary_w_bins['School Size'] = pd.cut(per_school_summary_w_bins['Total Students'].apply(lambda x: float(x.replace(',', ''))), bins=size_bins, labels=labels)
size_summary = per_school_summary_w_bins[['School Size',
    'Average Math Score',
    'Average Reading Score',
    '% Passing Math',
    '% Passing Reading',
    '% Overall Passing']].groupby(by=['School Size']).mean()

size_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math
# School Size
# Small (<1000)                83.821598              83.929843       93.550225  \
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %%
# use the `per_school_summary` data frame to analyze performance based on school type
type_summary = per_school_summary[['School Type',
    'Average Math Score',
    'Average Reading Score',
    '% Passing Math',
    '% Passing Reading',
    '% Overall Passing']].groupby(by=['School Type']).mean()

type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math
# School Type
# Charter               83.473852              83.896421       93.620830  \
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
